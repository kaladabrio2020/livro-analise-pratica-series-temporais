# %%
import plotly.express as px
import pandas as pd
import seaborn as sns

# %% [markdown]
# visulizacao 1d

# %%
donations = pd.read_csv('dataset/donations.csv')

# %%
donations['timestamp'] = pd.to_datetime(donations['timestamp']).dt.strftime('%Y-%m-%d')

# %%
subset = donations.groupby(['user'])['timestamp'].agg(['min', 'max']).reset_index()
subset.head()
# Out:
#    user         min         max
# 0   0.0  2015-03-26  2017-11-12
# 1   1.0  2016-05-05  2017-01-23
# 2   2.0  2016-03-15  2017-07-25
# 3   5.0  2017-07-28  2017-09-20
# 4   6.0  2017-07-06  2017-11-01

# %%
subset.sample(10),
# Out:
# (      user         min         max
#  192  326.0  2015-10-28  2018-02-05
#  402  685.0  2017-05-20  2017-05-20
#  503  883.0  2016-06-19  2018-03-13
#  121  204.0  2017-04-22  2018-01-13
#  111  181.0  2017-11-08  2018-04-20
#  492  866.0  2017-06-09  2018-05-24
#  516  904.0  2015-08-13  2017-11-20
#  494  871.0  2016-07-31  2017-12-31
#  188  319.0  2015-10-29  2018-05-31
#  366  626.0  2017-01-06  2017-09-04,)

# %%
fig = px.timeline(
    subset.sample(10),
    x_start="min",
    x_end="max",
    y="user",
    color="user",
    hover_name="user"
)
fig.show()

# %% [markdown]
# vizualização 2d

# %%
data = pd.read_csv('dataset/AirPassengers.csv')

# %%
sns.lineplot(data=data)
# Out:
# <Axes: >

# %%
data['mes'] = pd.to_datetime(data['Month']).dt.month_name('pt')

# %%
data['ano'] = pd.to_datetime(data['Month']).dt.year

# %%
sns.lineplot(data=data, y='#Passengers', x='mes', hue='ano')
# Out:
# <Axes: xlabel='mes', ylabel='#Passengers'>

# %%
sns.lineplot(data=data, y='#Passengers', x='ano', hue='mes')
# Out:
# <Axes: xlabel='ano', ylabel='#Passengers'>

# %%
sns.monhtplot(data=data, y='#Passengers', x='mes', hue='ano')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sns.monhtplot(data=data, y='#Passengers', x='mes', hue='ano')
#
# NameError: name 'sns' is not defined
